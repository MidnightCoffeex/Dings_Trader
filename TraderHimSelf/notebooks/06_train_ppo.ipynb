# %% [markdown]
# # 06_train_ppo
# Train PPO policy.

# %%
# %%bash
# set -euo pipefail
# STEP="06_train_ppo"
# ROOT="$(cd .. && pwd)"
# cd "$ROOT"
# mkdir -p logs/colab
# LOG="logs/colab/${STEP}.log"
# trap 'rc=$?; echo "ERROR: ${STEP} :: exit_code=${rc}" | tee -a "$LOG"; exit $rc' ERR
#
# echo "START: ${STEP}" | tee -a "$LOG"
# python policy/train_ppo.py 2>&1 | tee -a "$LOG"
# echo "OK: ${STEP}" | tee -a "$LOG"
